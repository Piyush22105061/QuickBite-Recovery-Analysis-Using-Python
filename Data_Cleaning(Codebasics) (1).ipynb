# %%
import numpy as np
import pandas as pd

# %%
df_order=pd.read_csv('fact_orders.csv')
df_order
# Out:
#                order_id customer_id restaurant_id delivery_partner_id  \
# 0       ORD202501023439  CUST181110     REST08622             DP05541
# 1       ORD202501012051  CUST025572     REST02383             DP08091
# 2       ORD202501019281  CUST179306     REST14069             DP02021
# 3       ORD202501000124  CUST191820     REST19745             DP13859
# 4       ORD202501006518  CUST033760     REST12962             DP09615
# ...                 ...         ...           ...                 ...
# 149161  ORD202509003524  CUST080037     REST12269             DP13152
# 149162  ORD202509007665  CUST014106     REST04052                 NaN
# 149163  ORD202509007687  CUST181895     REST07289             DP04700
# 149164  ORD202509002029  CUST089114     REST18195             DP12994
# 149165  ORD202509007649  CUST165574     REST04104             DP09675
#
#             order_timestamp  subtotal_amount  discount_amount  delivery_fee  \
# ...

# %%
df_order.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149166 entries, 0 to 149165
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             149166 non-null  object
#  1   customer_id          149166 non-null  object
#  2   restaurant_id        149166 non-null  object
#  3   delivery_partner_id  143531 non-null  object
#  4   order_timestamp      149166 non-null  object
#  5   subtotal_amount      149166 non-null  float64
#  6   discount_amount      149166 non-null  float64
#  7   delivery_fee         149166 non-null  float64
#  8   total_amount         149166 non-null  float64
#  9   is_cod               149166 non-null  object
#  10  is_cancelled         149166 non-null  object
# dtypes: float64(4), object(7)
# memory usage: 12.5+ MB

# %%
df_order.fillna('Not_available',inplace=True)
df_order[df_order['delivery_partner_id']=='Not_available']
# Out:
#                order_id customer_id restaurant_id delivery_partner_id  \
# 15      ORD202501011873  CUST050526     REST19508       Not_available
# 24      ORD202501022002  CUST114265     REST08397       Not_available
# 50      ORD202501012168  CUST119646     REST12616       Not_available
# 54      ORD202501023485  CUST056936     REST03176       Not_available
# 57      ORD202501000523  CUST195834     REST10055       Not_available
# ...                 ...         ...           ...                 ...
# 149097  ORD202509001260  CUST150817     REST07214       Not_available
# 149110  ORD202509009077  CUST024731     REST10666       Not_available
# 149146  ORD202509005099  CUST040380     REST14432       Not_available
# 149156  ORD202509003738  CUST147227     REST05675       Not_available
# 149162  ORD202509007665  CUST014106     REST04052       Not_available
#
#             order_timestamp  subtotal_amount  discount_amount  delivery_fee  \
# ...

# %%
df_order.describe()
# Out:
#        subtotal_amount  discount_amount   delivery_fee   total_amount
# count    149166.000000    149166.000000  149166.000000  149166.000000
# mean        314.373203        18.891589      30.069224     325.550833
# std         147.346779        29.801279      10.997816     146.790190
# min           0.000000         0.000000       0.000000       0.000000
# 25%         234.960000         0.000000      24.730000     249.842500
# 50%         309.070000         0.000000      31.485000     321.700000
# 75%         396.290000        34.690000      38.240000     406.590000
# max         900.000000       222.530000      45.000000     944.910000

# %%
df_order.drop_duplicates(subset='order_id',inplace=False)
# Out:
#                order_id customer_id restaurant_id delivery_partner_id  \
# 0       ORD202501023439  CUST181110     REST08622             DP05541
# 1       ORD202501012051  CUST025572     REST02383             DP08091
# 2       ORD202501019281  CUST179306     REST14069             DP02021
# 3       ORD202501000124  CUST191820     REST19745             DP13859
# 4       ORD202501006518  CUST033760     REST12962             DP09615
# ...                 ...         ...           ...                 ...
# 149161  ORD202509003524  CUST080037     REST12269             DP13152
# 149162  ORD202509007665  CUST014106     REST04052                 NaN
# 149163  ORD202509007687  CUST181895     REST07289             DP04700
# 149164  ORD202509002029  CUST089114     REST18195             DP12994
# 149165  ORD202509007649  CUST165574     REST04104             DP09675
#
#             order_timestamp  subtotal_amount  discount_amount  delivery_fee  \
# ...

# %%
df_order['order_id'].nunique()
# Out:
# 149166

# %%
df_order_items=pd.read_csv('fact_order_items.csv')
df_order_items
# Out:
#                order_id  item_id    menu_item_id restaurant_id  quantity  \
# 0       ORD202501006518  ITEM001  MENU12962_3216     REST12962         2
# 1       ORD202501006518  ITEM002  MENU12962_1962     REST12962         3
# 2       ORD202501019281  ITEM001  MENU14069_0510     REST14069         2
# 3       ORD202501019281  ITEM002  MENU14069_4308     REST14069         3
# 4       ORD202501023439  ITEM001  MENU08622_7574     REST08622         2
# ...                 ...      ...             ...           ...       ...
# 342989  ORD202509002029  ITEM003  MENU18195_3090     REST18195         1
# 342990  ORD202509002029  ITEM004  MENU18195_7326     REST18195         3
# 342991  ORD202509007649  ITEM001  MENU04104_0153     REST04104         2
# 342992  ORD202509007649  ITEM002  MENU04104_5636     REST04104         1
# 342993  ORD202509007649  ITEM003  MENU04104_5633     REST04104         1
#
#         unit_price  item_discount  line_total
# ...

# %%
df_ratings=pd.read_csv('fact_ratings.csv')
df_ratings
# Out:
#               order_id customer_id restaurant_id  rating  \
# 0      ORD202501023439  CUST181110     REST08622     4.5
# 1      ORD202501019281  CUST179306     REST14069     4.5
# 2      ORD202501018036  CUST093042     REST13907     5.0
# 3      ORD202501007724  CUST110825     REST08451     4.0
# 4      ORD202501002349  CUST181669     REST00225     4.4
# ...                ...         ...           ...     ...
# 68837              NaN         NaN           NaN     NaN
# 68838              NaN         NaN           NaN     NaN
# 68839              NaN         NaN           NaN     NaN
# 68840              NaN         NaN           NaN     NaN
# 68841              NaN         NaN           NaN     NaN
#
#                 review_text  review_timestamp  sentiment_score
# 0       Super fast delivery  01-01-2025 15:00             0.75
# 1              Great taste!  01-01-2025 15:00             0.75
# 2       Super fast delivery  01-01-2025 14:03             1.00
# ...

# %%
df_ratings.dropna(thresh=7,inplace=True)
df_ratings.reset_index(drop=True,inplace=True)
df_ratings
# Out:
#               order_id customer_id restaurant_id  rating  \
# 0      ORD202501023439  CUST181110     REST08622     4.5
# 1      ORD202501019281  CUST179306     REST14069     4.5
# 2      ORD202501018036  CUST093042     REST13907     5.0
# 3      ORD202501007724  CUST110825     REST08451     4.0
# 4      ORD202501002349  CUST181669     REST00225     4.4
# ...                ...         ...           ...     ...
# 68820  ORD202509009609  CUST057825     REST01490     2.2
# 68821  ORD202509004269  CUST114184     REST16601     3.6
# 68822  ORD202509006794  CUST173128     REST11207     1.2
# 68823  ORD202509008376  CUST135098     REST05223     2.1
# 68824  ORD202509002465  CUST056144     REST19517     2.1
#
#                 review_text  review_timestamp  sentiment_score
# 0       Super fast delivery  01-01-2025 15:00             0.75
# 1              Great taste!  01-01-2025 15:00             0.75
# 2       Super fast delivery  01-01-2025 14:03             1.00
# ...

# %%
df_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68825 entries, 0 to 68824
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          68825 non-null  object
#  1   customer_id       68825 non-null  object
#  2   restaurant_id     68825 non-null  object
#  3   rating            68825 non-null  float64
#  4   review_text       68825 non-null  object
#  5   review_timestamp  68825 non-null  object
#  6   sentiment_score   68825 non-null  float64
# dtypes: float64(2), object(5)
# memory usage: 3.7+ MB

# %%
df_ratings.describe()
# Out:
#              rating  sentiment_score
# count  68825.000000     68825.000000
# mean       4.052308         0.526154
# std        0.940331         0.470165
# min        1.000000        -1.000000
# 25%        3.800000         0.400000
# 50%        4.400000         0.700000
# 75%        4.700000         0.850000
# max        5.000000         1.000000

# %%
df_ratings.drop_duplicates(subset='order_id',inplace=True)
df_ratings
# Out:
#               order_id customer_id restaurant_id  rating  \
# 0      ORD202501023439  CUST181110     REST08622     4.5
# 1      ORD202501019281  CUST179306     REST14069     4.5
# 2      ORD202501018036  CUST093042     REST13907     5.0
# 3      ORD202501007724  CUST110825     REST08451     4.0
# 4      ORD202501002349  CUST181669     REST00225     4.4
# ...                ...         ...           ...     ...
# 68820  ORD202509009609  CUST057825     REST01490     2.2
# 68821  ORD202509004269  CUST114184     REST16601     3.6
# 68822  ORD202509006794  CUST173128     REST11207     1.2
# 68823  ORD202509008376  CUST135098     REST05223     2.1
# 68824  ORD202509002465  CUST056144     REST19517     2.1
#
#                 review_text  review_timestamp  sentiment_score
# 0       Super fast delivery  01-01-2025 15:00             0.75
# 1              Great taste!  01-01-2025 15:00             0.75
# 2       Super fast delivery  01-01-2025 14:03             1.00
# ...

# %%
df_delivery_performance=pd.read_csv('fact_delivery_performance.csv')
df_delivery_performance
# Out:
#                order_id  actual_delivery_time_mins  \
# 0       ORD202501023439                         31
# 1       ORD202501012051                         46
# 2       ORD202501019281                         25
# 3       ORD202501000124                         29
# 4       ORD202501006518                         37
# ...                 ...                        ...
# 149161  ORD202509003524                         72
# 149162  ORD202509007665                         58
# 149163  ORD202509007687                         49
# 149164  ORD202509002029                         50
# 149165  ORD202509007649                         74
#
#         expected_delivery_time_mins  distance_km
# 0                                31          6.4
# 1                                42          1.9
# 2                                31          6.2
# 3                                41          6.2
# 4                                41          2.4
# ...                             ...          ...
# ...

# %%
df_delivery_performance.drop_duplicates(subset='order_id',inplace=True)
df_delivery_performance
# Out:
#                order_id  actual_delivery_time_mins  \
# 0       ORD202501023439                         31
# 1       ORD202501012051                         46
# 2       ORD202501019281                         25
# 3       ORD202501000124                         29
# 4       ORD202501006518                         37
# ...                 ...                        ...
# 149161  ORD202509003524                         72
# 149162  ORD202509007665                         58
# 149163  ORD202509007687                         49
# 149164  ORD202509002029                         50
# 149165  ORD202509007649                         74
#
#         expected_delivery_time_mins  distance_km
# 0                                31          6.4
# 1                                42          1.9
# 2                                31          6.2
# 3                                41          6.2
# 4                                41          2.4
# ...                             ...          ...
# ...

# %%
df_delivery_performance.describe()
# Out:
#        actual_delivery_time_mins  expected_delivery_time_mins    distance_km
# count              149166.000000                149166.000000  149166.000000
# mean                   44.404549                    38.691679       4.494667
# std                    12.784224                     5.074100       2.021213
# min                    25.000000                    30.000000       1.000000
# 25%                    36.000000                    35.000000       2.700000
# 50%                    42.000000                    39.000000       4.500000
# 75%                    50.000000                    43.000000       6.200000
# max                    90.000000                    50.000000       8.000000

# %%
df_delivery_performance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149166 entries, 0 to 149165
# Data columns (total 4 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   order_id                     149166 non-null  object
#  1   actual_delivery_time_mins    149166 non-null  int64
#  2   expected_delivery_time_mins  149166 non-null  int64
#  3   distance_km                  149166 non-null  float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 4.6+ MB

# %%
df_restaurant=pd.read_csv('dim_restaurant.csv')
df_restaurant
# Out:
#       restaurant_id                  restaurant_name       city  cuisine_type  \
# 0         REST12962        Flavours of Sweets Palace  Bengaluru       Chinese
# 1         REST14069             Royal Biryani Darbar  Ahmedabad     Fast Food
# 2         REST08622                Spicy Wraps Point     Mumbai  North Indian
# 3         REST19745             Delhi Express Palace  Ahmedabad         Pizza
# 4         REST02383               Namma Mess Delight     Mumbai       Healthy
# ...             ...                              ...        ...           ...
# 19990     REST09248              Fresh Sweets Clouds    Chennai  South Indian
# 19991     REST11150         Thindi Mane Express Zone     Mumbai     Fast Food
# 19992     REST07315                Delhi Cafe Heaven  Hyderabad       Biryani
# 19993     REST16252              Taste of Wraps Cafe  Ahmedabad  South Indian
# 19994     REST18157  Hot & Crispy Biryani Bhojanalay  Bengaluru       Chinese
#
# ...

# %%
df_restaurant.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19995 entries, 0 to 19994
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   restaurant_id      19995 non-null  object
#  1   restaurant_name    19995 non-null  object
#  2   city               19995 non-null  object
#  3   cuisine_type       19995 non-null  object
#  4   partner_type       19995 non-null  object
#  5   avg_prep_time_min  19995 non-null  object
#  6   is_active          19995 non-null  object
# dtypes: object(7)
# memory usage: 1.1+ MB

# %%
df_restaurant['restaurant_name'].value_counts()
# Out:
# restaurant_name
# Classic Tandoor Heaven          12
# Hot & Crispy Biryani Heaven     12
# Punjabi Express Central         12
# Tandoori Curry Nest             11
# Thindi Mane Grill Darbar        11
#                                 ..
# Thindi Mane Curry Bhojanalay     1
# Annapurna Mess Mahal             1
# Taste of Thali Heaven            1
# Bombay Delights Hub              1
# Taste of Tandoor Clouds          1
# Name: count, Length: 4779, dtype: int64

# %%
df_restaurant[df_restaurant['restaurant_name']=='Classic Tandoor Heaven']
# Out:
#       restaurant_id         restaurant_name       city  cuisine_type  \
# 2395      REST13701  Classic Tandoor Heaven     Mumbai       Biryani
# 3183      REST19495  Classic Tandoor Heaven  Hyderabad       Chinese
# 5001      REST03282  Classic Tandoor Heaven       Pune       Chinese
# 6664      REST17389  Classic Tandoor Heaven      Delhi  North Indian
# 10447     REST12337  Classic Tandoor Heaven    Kolkata  North Indian
# 12164     REST02288  Classic Tandoor Heaven    Kolkata  North Indian
# 14048     REST17427  Classic Tandoor Heaven  Ahmedabad  North Indian
# 15351     REST01743  Classic Tandoor Heaven    Chennai  South Indian
# 15461     REST10988  Classic Tandoor Heaven       Pune         Pizza
# 18386     REST12451  Classic Tandoor Heaven  Bengaluru     Fast Food
# 19027     REST16889  Classic Tandoor Heaven     Mumbai  South Indian
# 19347     REST16470  Classic Tandoor Heaven       Pune       Biryani
#
#         partner_type avg_prep_time_min is_active
# ...

# %%
df_menu_item=pd.read_csv('dim_menu_item.csv')
df_menu_item
# Out:
#           menu_item_id restaurant_id           item_name    category is_veg  \
# 0       MENU12962_3216     REST12962  Paneer Tikka Pizza       Pizza      Y
# 1       MENU12962_1962     REST12962     Pepperoni Pizza       Pizza      N
# 2       MENU14069_0510     REST14069      Egg Fried Rice  Fried Rice      N
# 3       MENU14069_4308     REST14069        Paneer Tikka    Starters      Y
# 4       MENU08622_7574     REST08622        Kadai Paneer     Curries      Y
# ...                ...           ...                 ...         ...    ...
# 342666  MENU18195_3090     REST18195          Lemon Rice        Rice      Y
# 342667  MENU18195_7326     REST18195         Idli Sambar        Idli      N
# 342668  MENU04104_0153     REST04104        French Fries       Fries      Y
# 342669  MENU04104_5636     REST04104  Chicken Kathi Roll       Wraps      N
# 342670  MENU04104_5633     REST04104            Veg Wrap       Wraps      Y
#
#          price
# 0       271.05
# 1       327.26
# ...

# %%
df_menu_item.drop_duplicates(subset='menu_item_id',inplace=True)
df_menu_item
# Out:
#           menu_item_id restaurant_id           item_name    category is_veg  \
# 0       MENU12962_3216     REST12962  Paneer Tikka Pizza       Pizza      Y
# 1       MENU12962_1962     REST12962     Pepperoni Pizza       Pizza      N
# 2       MENU14069_0510     REST14069      Egg Fried Rice  Fried Rice      N
# 3       MENU14069_4308     REST14069        Paneer Tikka    Starters      Y
# 4       MENU08622_7574     REST08622        Kadai Paneer     Curries      Y
# ...                ...           ...                 ...         ...    ...
# 342666  MENU18195_3090     REST18195          Lemon Rice        Rice      Y
# 342667  MENU18195_7326     REST18195         Idli Sambar        Idli      N
# 342668  MENU04104_0153     REST04104        French Fries       Fries      Y
# 342669  MENU04104_5636     REST04104  Chicken Kathi Roll       Wraps      N
# 342670  MENU04104_5633     REST04104            Veg Wrap       Wraps      Y
#
#          price
# 0       271.05
# 1       327.26
# ...

# %%
df_menu_item.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 342671 entries, 0 to 342670
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   menu_item_id   342671 non-null  object
#  1   restaurant_id  342671 non-null  object
#  2   item_name      342671 non-null  object
#  3   category       342671 non-null  object
#  4   is_veg         342671 non-null  object
#  5   price          342671 non-null  float64
# dtypes: float64(1), object(5)
# memory usage: 15.7+ MB

# %%
df_menu_item.describe()
# Out:
#                price
# count  342671.000000
# mean      164.332567
# std        69.083017
# min        25.000000
# 25%       114.980000
# 50%       157.340000
# 75%       207.200000
# max       449.990000

# %%
df_delivery_partner=pd.read_csv('dim_delivery_partner_.csv')
df_delivery_partner
# Out:
#       delivery_partner_id partner_name       city vehicle_type  \
# 0                 DP09615       Neha E  Bengaluru      Scooter
# 1                 DP02021       Neha V  Bengaluru         Bike
# 2                 DP05541      Vikas S      Delhi        Cycle
# 3                 DP13859       Amit B      Delhi        Cycle
# 4                 DP08091      Arjun R     Mumbai          Car
# ...                   ...          ...        ...          ...
# 14995             DP05518       Neha W       Pune         Bike
# 14996             DP01199     Shreya J    Chennai         Bike
# 14997             DP07045     Suresh M      Delhi         Bike
# 14998             DP09075      Vikas H    Chennai      Scooter
# 14999             DP07749      Rahul F    Kolkata      Scooter
#
#       employment_type  avg_rating is_active
# 0           Full-time        3.77         Y
# 1           Full-time        3.90         Y
# 2           Part-time        3.33         Y
# ...

# %%
df_delivery_partner.isna().sum()
# Out:
# delivery_partner_id    0
# partner_name           0
# city                   0
# vehicle_type           0
# employment_type        0
# avg_rating             0
# is_active              0
# dtype: int64

# %%
df_customer=pd.read_csv('dim_customer.csv')
df_customer
# Out:
#        customer_id signup_date       city acquisition_channel
# 0       CUST000007  21-03-2025       Pune             Organic
# 1       CUST000008  07-02-2025    Kolkata            Referral
# 2       CUST000009  25-02-2025      Delhi                Paid
# 3       CUST000010  28-01-2025  Hyderabad                Paid
# 4       CUST000011  18-01-2025    Kolkata             Organic
# ...            ...         ...        ...                 ...
# 107771  CUST199995  19-11-2024      Delhi             Organic
# 107772  CUST199996  14-01-2025  Hyderabad              Social
# 107773  CUST199997  22-12-2024  Hyderabad             Organic
# 107774  CUST199999  11-05-2025     Mumbai             Organic
# 107775  CUST200000  25-02-2025    Chennai             Organic
#
# [107776 rows x 4 columns]

# %%
df_customer.isna().sum()
# Out:
# customer_id            0
# signup_date            0
# city                   0
# acquisition_channel    0
# dtype: int64

# %%
df_customer.acquisition_channel.unique()
# Out:
# array(['Organic', 'Referral', 'Paid', 'Social'], dtype=object)

# %%
df_customer.city.unique()
# Out:
# array(['Pune', 'Kolkata', 'Delhi', 'Hyderabad', 'Bengaluru', 'Ahmedabad',
#        'Mumbai', 'Chennai'], dtype=object)

# %%
df_customer.drop_duplicates(subset='customer_id',inplace=True)
df_customer
# Out:
#        customer_id signup_date       city acquisition_channel
# 0       CUST000007  21-03-2025       Pune             Organic
# 1       CUST000008  07-02-2025    Kolkata            Referral
# 2       CUST000009  25-02-2025      Delhi                Paid
# 3       CUST000010  28-01-2025  Hyderabad                Paid
# 4       CUST000011  18-01-2025    Kolkata             Organic
# ...            ...         ...        ...                 ...
# 107771  CUST199995  19-11-2024      Delhi             Organic
# 107772  CUST199996  14-01-2025  Hyderabad              Social
# 107773  CUST199997  22-12-2024  Hyderabad             Organic
# 107774  CUST199999  11-05-2025     Mumbai             Organic
# 107775  CUST200000  25-02-2025    Chennai             Organic
#
# [107776 rows x 4 columns]

# %%
df_customer.to_csv('dim_cleaned_customer.csv',index=False)
df_delivery_partner.to_csv('dim_cleaned_delivery_partner.csv',index=False)
df_menu_item.to_csv('dim_cleaned_menu_item.csv',index=False)
df_restaurant.to_csv('dim_cleaned_restaurant.csv',index=False)
df_delivery_performance.to_csv('fact_cleaned_delivery_performance.csv',index=False)
df_ratings.to_csv('fact_cleaned_ratings.csv',index=False)
df_order_items.to_csv('fact_cleaned_order_items.csv',index=False)
df_order.to_csv('fact_cleaned_orders.csv',index=False)
